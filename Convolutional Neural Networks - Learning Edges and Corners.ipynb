# %%
import numpy as np, sys
np.random.seed(1)

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
images, labels = (x_train[0:1000].reshape(1000,28*28) / 255,
                  y_train[0:1000])


one_hot_labels = np.zeros((len(labels),10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

alpha, iterations = (2, 100)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * 
               (input_cols - kernel_cols)) * num_kernels

# weights_0_1 = 0.02*np.random.random((pixels_per_image,hidden_size))-0.01
kernels = 0.02*np.random.random((kernel_rows*kernel_cols,
                                 num_kernels))-0.01

weights_1_2 = 0.2*np.random.random((hidden_size,
                                    num_labels)) - 0.1

# %%
def get_image_section(layer,row_from, row_to, col_from, col_to):
    section = layer[:,row_from:row_to,col_from:col_to]
    return section.reshape(-1,1,row_to-row_from, col_to-col_from)

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end=((i * batch_size),((i+1)*batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2))

        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == 
                               np.argmax(labelset))
            correct_cnt += _inc

        layer_2_delta = (labels[batch_start:batch_end]-layer_2)\
                        / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * \
                        tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
    
    test_correct_cnt = 0

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
#         layer_1 = tanh(np.dot(layer_0,weights_0_1))
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        layer_2 = np.dot(layer_1,weights_1_2)

        test_correct_cnt += int(np.argmax(layer_2) == 
                                np.argmax(test_labels[i:i+1]))
    if(j % 1 == 0):
        sys.stdout.write("\n"+ \
         "I:" + str(j) + \
         " Test-Acc:"+str(test_correct_cnt/float(len(test_images)))+\
         " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
# I:0 Test-Acc:0.0874 Train-Acc:0.099
# I:1 Test-Acc:0.0685 Train-Acc:0.078
# I:2 Test-Acc:0.0705 Train-Acc:0.08
# I:3 Test-Acc:0.0775 Train-Acc:0.072
# I:4 Test-Acc:0.0942 Train-Acc:0.088
# I:5 Test-Acc:0.1283 Train-Acc:0.106
# I:6 Test-Acc:0.1728 Train-Acc:0.128
# I:7 Test-Acc:0.2134 Train-Acc:0.128
# I:8 Test-Acc:0.2547 Train-Acc:0.162
# I:9 Test-Acc:0.2971 Train-Acc:0.171
# I:10 Test-Acc:0.3347 Train-Acc:0.2
# I:11 Test-Acc:0.3558 Train-Acc:0.238
# I:12 Test-Acc:0.3454 Train-Acc:0.259
# I:13 Test-Acc:0.2836 Train-Acc:0.238
# I:14 Test-Acc:0.1312 Train-Acc:0.164
# I:15 Test-Acc:0.0325 Train-Acc:0.087
# I:16 Test-Acc:0.0124 Train-Acc:0.03
# I:17 Test-Acc:0.0126 Train-Acc:0.023
# I:18 Test-Acc:0.0167 Train-Acc:0.034
# I:19 Test-Acc:0.0272 Train-Acc:0.028
# I:20 Test-Acc:0.057 Train-Acc:0.045
# I:21 Test-Acc:0.1192 Train-Acc:0.079
# I:22 Test-Acc:0.1912 Train-Acc:0.101
# I:23 Test-Acc:0.3043 Train-Acc:0.165
# I:24 Test-Acc:0.4071 Train-Acc:0.195
# I:25 Test-Acc:0.4807 Train-Acc:0.286
# I:26 Test-Acc:0.5341 Train-Acc:0.288
# I:27 Test-Acc:0.5695 Train-Acc:0.329
# I:28 Test-Acc:0.6006 Train-Acc:0.395
# I:29 Test-Acc:0.62 Train-Acc:0.42
# I:30 Test-Acc:0.6386 Train-Acc:0.449
# I:31 Test-Acc:0.6535 Train-Acc:0.45
# I:32 Test-Acc:0.6653 Train-Acc:0.459
# I:33 Test-Acc:0.6766 Train-Acc:0.481
# I:34 Test-Acc:0.688 Train-Acc:0.48
# I:35 Test-Acc:0.6963 Train-Acc:0.465
# I:36 Test-Acc:0.7035 Train-Acc:0.495
# I:37 Test-Acc:0.7118 Train-Acc:0.5
# I:38 Test-Acc:0.7182 Train-Acc:0.511
# I:39 Test-Acc:0.7205 Train-Acc:0.525
# I:40 Test-Acc:0.7258 Train-Acc:0.523
# I:41 Test-Acc:0.7307 Train-Acc:0.527
# I:42 Test-Acc:0.7321 Train-Acc:0.532
# I:43 Test-Acc:0.7365 Train-Acc:0.543
# I:44 Test-Acc:0.7321 Train-Acc:0.546
# I:45 Test-Acc:0.7342 Train-Acc:0.523
# I:46 Test-Acc:0.7357 Train-Acc:0.525
# I:47 Test-Acc:0.7393 Train-Acc:0.548
# I:48 Test-Acc:0.7387 Train-Acc:0.517
# I:49 Test-Acc:0.7404 Train-Acc:0.52
# I:50 Test-Acc:0.7358 Train-Acc:0.538
# I:51 Test-Acc:0.7381 Train-Acc:0.514
# I:52 Test-Acc:0.738 Train-Acc:0.54
# I:53 Test-Acc:0.7354 Train-Acc:0.504
# I:54 Test-Acc:0.7215 Train-Acc:0.49
# I:55 Test-Acc:0.7114 Train-Acc:0.431
# I:56 Test-Acc:0.7093 Train-Acc:0.41
# I:57 Test-Acc:0.7056 Train-Acc:0.435
# I:58 Test-Acc:0.7129 Train-Acc:0.428
# I:59 Test-Acc:0.6961 Train-Acc:0.427
# I:60 Test-Acc:0.6938 Train-Acc:0.424
# I:61 Test-Acc:0.681 Train-Acc:0.383
# I:62 Test-Acc:0.7034 Train-Acc:0.396
# I:63 Test-Acc:0.7222 Train-Acc:0.421
# I:64 Test-Acc:0.731 Train-Acc:0.449
# I:65 Test-Acc:0.7404 Train-Acc:0.458
# I:66 Test-Acc:0.7503 Train-Acc:0.472
# I:67 Test-Acc:0.7546 Train-Acc:0.478
# I:68 Test-Acc:0.7563 Train-Acc:0.521
# I:69 Test-Acc:0.7646 Train-Acc:0.521
# I:70 Test-Acc:0.7753 Train-Acc:0.531
# I:71 Test-Acc:0.7791 Train-Acc:0.562
# I:72 Test-Acc:0.7867 Train-Acc:0.56
# I:73 Test-Acc:0.7971 Train-Acc:0.571
# I:74 Test-Acc:0.7971 Train-Acc:0.573
# I:75 Test-Acc:0.8069 Train-Acc:0.584
# I:76 Test-Acc:0.8113 Train-Acc:0.621
# I:77 Test-Acc:0.8125 Train-Acc:0.628
# I:78 Test-Acc:0.8146 Train-Acc:0.618
# I:79 Test-Acc:0.8207 Train-Acc:0.643
# I:80 Test-Acc:0.8218 Train-Acc:0.644
# I:81 Test-Acc:0.8275 Train-Acc:0.652
# I:82 Test-Acc:0.8237 Train-Acc:0.659
# I:83 Test-Acc:0.83 Train-Acc:0.676
# I:84 Test-Acc:0.8314 Train-Acc:0.68
# I:85 Test-Acc:0.8343 Train-Acc:0.672
# I:86 Test-Acc:0.8382 Train-Acc:0.676
# I:87 Test-Acc:0.8406 Train-Acc:0.686
# I:88 Test-Acc:0.8413 Train-Acc:0.694
# I:89 Test-Acc:0.8405 Train-Acc:0.682
# I:90 Test-Acc:0.8433 Train-Acc:0.694
# I:91 Test-Acc:0.8468 Train-Acc:0.692
# I:92 Test-Acc:0.8419 Train-Acc:0.728
# I:93 Test-Acc:0.8481 Train-Acc:0.708
# I:94 Test-Acc:0.846 Train-Acc:0.718
# I:95 Test-Acc:0.85 Train-Acc:0.709
# I:96 Test-Acc:0.8497 Train-Acc:0.713
# I:97 Test-Acc:0.8516 Train-Acc:0.697
# I:98 Test-Acc:0.854 Train-Acc:0.71
# I:99 Test-Acc:0.851 Train-Acc:0.706
